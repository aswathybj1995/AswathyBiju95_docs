# %%
# import all libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset

# %%
data=pd.read_csv(r'C:\Users\aswat\Downloads\car_age_price.csv')

# %%
data
# Out:
#      Year   Price
# 0    2018  465000
# 1    2019  755000
# 2    2019  700000
# 3    2018  465000
# 4    2018  465000
# ..    ...     ...
# 107  2016  375000
# 108  2014  300000
# 109  2015  425000
# 110  2016  420000
# 111  2015  425000
#
# [112 rows x 2 columns]

# %%
# to find first 5 rows

# %%
data.head()
# Out:
#    Year   Price
# 0  2018  465000
# 1  2019  755000
# 2  2019  700000
# 3  2018  465000
# 4  2018  465000

# %%
# to find no of rows and columns

# %%
data.shape
# Out:
# (112, 2)

# %%
# to get description of data in each columns

# %%
data.describe()
# Out:
#               Year          Price
# count   112.000000     112.000000
# mean   2016.669643  483866.044643
# std       1.629616   91217.450533
# min    2013.000000  300000.000000
# 25%    2015.000000  423750.000000
# 50%    2017.000000  500000.000000
# 75%    2017.000000  550000.000000
# max    2020.000000  755000.000000

# %%
# to get informations such as no of columns,data types,null values,range index etc

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    112 non-null    int64
#  1   Price   112 non-null    int64
# dtypes: int64(2)
# memory usage: 1.9 KB

# %%
# to find unique values

# %%
data['Year'].unique()
# Out:
# array([2018, 2019, 2015, 2016, 2017, 2020, 2013, 2014], dtype=int64)

# %%
data['Price'].unique()
# Out:
# array([465000, 755000, 700000, 350000, 425000, 575000, 509999, 500000,
#        600000, 475000, 550000, 434999, 650000, 450000, 486000, 545000,
#        525000, 396000, 325000, 345000, 341000, 490000, 540000, 595000,
#        495000, 400000, 300000, 320000, 409999, 390000, 480000, 520000,
#        640000, 375000, 420000], dtype=int64)

# %%
# to get no of unique values

# %%
data['Year'].nunique()
# Out:
# 8

# %%
data['Price'].nunique()
# Out:
# 35

# %%
# Check for Null values

# %%
data.isna().sum()
# Out:
# Year     0
# Price    0
# dtype: int64

# %%
# frequency graph-histogram

# %%
freqgraph=data.select_dtypes(include=['int'])
freqgraph.hist(figsize=(20,15))
plt.show()

# %%
# Correlation Matrix-Heatmap

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,annot=True,vmin=0.5,vmax=1,linewidth=0.3,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
# Linear Regression-Taking independent variable(Year) to x and dependent variable(Price) to y

# %%
y=data['Price']
x=data.drop(['Price'],axis=1)
y
# Out:
# 0      465000
# 1      755000
# 2      700000
# 3      465000
# 4      465000
#         ...
# 107    375000
# 108    300000
# 109    425000
# 110    420000
# 111    425000
# Name: Price, Length: 112, dtype: int64

# %%
x
# Out:
#      Year
# 0    2018
# 1    2019
# 2    2019
# 3    2018
# 4    2018
# ..    ...
# 107  2016
# 108  2014
# 109  2015
# 110  2016
# 111  2015
#
# [112 rows x 1 columns]

# %%
#Split the data for training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
# Creating instance for the linear model

# %%
from sklearn import linear_model
lr=linear_model.LinearRegression()

# %%
# Creating model

# %%
model=lr.fit(x_train,y_train)

# %%
# Test the model

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([599223.07304102, 505265.04214995, 552244.05759548, 552244.05759548,
#        552244.05759548, 411307.01125886, 505265.04214995, 552244.05759548,
#        599223.07304102, 599223.07304102, 317348.98036776, 505265.04214995,
#        411307.01125886, 646202.08848657, 552244.05759548, 599223.07304102,
#        317348.98036776, 411307.01125886, 505265.04214995, 505265.04214995,
#        505265.04214995, 505265.04214995, 505265.04214995, 505265.04214995,
#        505265.04214995, 505265.04214995, 411307.01125886, 411307.01125886])

# %%
y_test
# Out:
# 40     525000
# 65     495000
# 4      465000
# 47     450000
# 42     550000
# 69     300000
# 26     550000
# 11     500000
# 10     500000
# 44     550000
# 73     320000
# 55     550000
# 68     465000
# 97     640000
# 0      465000
# 18     500000
# 53     345000
# 80     390000
# 103    375000
# 91     520000
# 36     550000
# 12     500000
# 31     550000
# 66     525000
# 90     520000
# 62     540000
# 22     434999
# 85     320000
# Name: Price, dtype: int64

# %%
# import MSE, r^2 to Evaluate the models with MSE & r^2 , print the scores

# %%
from sklearn.metrics import mean_squared_error,r2_score
print('MSE = ',mean_squared_error(y_test,y_pred))
print('r2 score = ',r2_score(y_test,y_pred))
# Out:
# MSE =  3878767151.0727544
# r2 score =  0.43479616321090353

# %%
# Lasso Regression importing from sklearn linear_model

# %%
from sklearn import linear_model
ls=linear_model.Lasso()

# %%
model1=ls.fit(x_train,y_train)

# %%
y_pred1=model1.predict(x_test)

# %%
y_test
# Out:
# 40     525000
# 65     495000
# 4      465000
# 47     450000
# 42     550000
# 69     300000
# 26     550000
# 11     500000
# 10     500000
# 44     550000
# 73     320000
# 55     550000
# 68     465000
# 97     640000
# 0      465000
# 18     500000
# 53     345000
# 80     390000
# 103    375000
# 91     520000
# 36     550000
# 12     500000
# 31     550000
# 66     525000
# 90     520000
# 62     540000
# 22     434999
# 85     320000
# Name: Price, dtype: int64

# %%
from sklearn.metrics import mean_squared_error,r2_score
print('MSE = ',mean_squared_error(y_test,y_pred1))
print("r2 score= ",r2_score(y_test,y_pred1))
# Out:
# MSE =  3878735896.222091
# r2 score=  0.4348007175862566

# %%
# Predict the price of a 2022 model second-hand Grand i10 using Linear

# %%
pred_price=model.predict([[2022]])[0]
print("Predicted price of a 2022 model second-hand Grand i10:", pred_price)
# Out:
# Predicted price of a 2022 model second-hand Grand i10: 740160.1193776578
# C:\Users\aswat\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Predict the price of a 2022 model second-hand Grand i10 using Lasso

# %%
pred_price1=model1.predict([[2022]])[0]
print("Predicted price of a 2022 model second-hand Grand i10:", pred_price1)
# Out:
# Predicted price of a 2022 model second-hand Grand i10: 740157.9570014179
# C:\Users\aswat\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(

# %%
# Scatter plot for various Year and Price

# %%
plt.scatter(x_test,y_pred)
plt.subplot(1,2,1)
plt.plot(x_test,y_pred, color='red',marker='+')
plt.title("Linear Regression")
plt.subplot(1,2,2)
plt.plot(x_test,y_pred1, color='green',marker='o')
plt.title("Lasso Regression")
plt.show()

# %%
# Determine which model is performing better

# %%
if r2_score(y_test,y_pred)>r2_score(y_test,y_pred1):
    print("Linear Regression is performing Better")
else:
    print("Lasso Regression is performing Better")
# Out:
# Lasso Regression is performing Better
